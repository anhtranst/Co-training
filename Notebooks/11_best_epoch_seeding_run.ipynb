# %% [markdown]
# # LG-CoTrain: Best-Epoch Phase 1 Seeding — Full Run with Optuna Hyperparameters
#
# This notebook runs the **complete experiment sweep** (all events x all budgets x all seeds)
# using **`phase1_seed_strategy="best"`** — our experimental extension that seeds Phase 2
# from the Phase 1 epoch with the highest ensemble dev macro-F1, rather than the last epoch.
#
# | Setting | Value |
# |---|---|
# | Phase 1 seed strategy | `best` (seed from best-performing Phase 1 epoch) |
# | Stopping strategy | `baseline` (paper's Algorithm 1: patience on ensemble macro-F1) |
# | Hyperparameters | Per-experiment Optuna-tuned (same as Notebook 10) |
# | Results path | `results/gpt-4o/test/run-4` |
#
# **Total experiments**: 10 events x 4 budgets x 3 seeds = **120 runs**
#
# **Key question**: Does seeding Phase 2 from the best Phase 1 epoch (by ensemble dev
# macro-F1) produce better final models than the paper's default of using the last epoch?
# The hypothesis is that Phase 1 models — trained on very small labeled splits — may overfit
# in later epochs, and seeding from the best-generalizing epoch could yield better-calibrated
# lambda weights for Phase 2 co-training.
#
# **Comparison baseline**: Notebook 10's `baseline` strategy results (same Optuna hyperparams,
# but `phase1_seed_strategy="last"`).
#
# ## Resume Support
#
# Every `(event, budget, seed_set)` combination is written to its own `metrics.json`
# as soon as it completes. Re-running any cell automatically skips completed experiments.

# %%
import json
import statistics
import sys
import time
from pathlib import Path


def _find_repo_root(marker: str = "lg_cotrain") -> Path:
    for candidate in [Path().resolve()] + list(Path().resolve().parents):
        if (candidate / marker).is_dir():
            return candidate
    raise RuntimeError(
        f"Cannot find repo root: no ancestor directory contains '{marker}/'. "
        "Run the notebook from inside the repository."
    )


repo_root = _find_repo_root()
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

import matplotlib.pyplot as plt
import numpy as np

from lg_cotrain.run_all import BUDGETS, SEED_SETS, format_summary_table, run_all_experiments
from lg_cotrain.parallel import run_experiments_parallel
from lg_cotrain.optuna_per_experiment import load_best_params


class ProgressTracker:
    """Track global progress across all events x budgets x seeds."""

    def __init__(self, total: int, already_done: int, start_time: float):
        self.total = total
        self.done = already_done
        self.start_time = start_time

    def update(self, event, budget, seed_set, status):
        self.done += 1
        elapsed = time.time() - self.start_time
        pct = 100.0 * self.done / self.total if self.total else 0
        elapsed_h = elapsed / 3600
        remaining = self.total - self.done
        eta_h = (elapsed / self.done) * remaining / 3600 if self.done > 0 else 0
        print(
            f"  [PROGRESS] {self.done}/{self.total} ({pct:.1f}%)"
            f"  |  Elapsed: {elapsed_h:.2f}h  |  ETA: {eta_h:.2f}h  |  {status}"
        )


print(f"Repo root : {repo_root}")
print(f"Budgets   : {BUDGETS}")
print(f"Seed sets : {SEED_SETS}")
# Out:
# Repo root : D:\Workspace\Co-Training
# Budgets   : [5, 10, 25, 50]
# Seed sets : [1, 2, 3]

# %%
# ---- Configuration ----

PSEUDO_LABEL_SOURCE = "gpt-4o"

# Number of GPUs for parallel execution (1 = sequential fallback)
NUM_GPUS = 2

# Optuna trial count to load (None = latest available)
N_TRIALS = 10

# Phase 1 seed strategy: "best" = seed from best Phase 1 epoch (our extension)
PHASE1_SEED_STRATEGY = "best"

# Only baseline stopping strategy (paper's Algorithm 1)
STOPPING_STRATEGY = "baseline"

DATA_ROOT = str(repo_root / "data")

# Results destination
RESULTS_ROOT = str(repo_root / "results" / "gpt-4o" / "test" / "run-4")

# Discover all events
TARGET_EVENTS = sorted(
    p.name for p in (Path(DATA_ROOT) / "original").iterdir() if p.is_dir()
)

# ---- Load Optuna best params for ALL (event, budget, seed_set) combos ----
OPTUNA_DIR = str(repo_root / "results" / "optuna" / "per_experiment")
optuna_results = load_best_params(
    storage_dir=OPTUNA_DIR,
    n_trials=N_TRIALS,
)

# Default hyperparams (fallback when Optuna results are missing)
DEFAULT_PARAMS = {
    "lr": 2e-5,
    "batch_size": 32,
    "cotrain_epochs": 10,
    "finetune_patience": 5,
    "weight_decay": 0.01,
    "warmup_ratio": 0.1,
}

# Build per-experiment param lookup: (event, budget, seed_set) -> params dict
experiment_params = {}  # key -> 6-hyperparam dict
missing_keys = []
for event in TARGET_EVENTS:
    for budget in BUDGETS:
        for seed_set in SEED_SETS:
            key = (event, budget, seed_set)
            if key in optuna_results:
                experiment_params[key] = optuna_results[key]["best_params"]
            else:
                experiment_params[key] = None  # will use defaults
                missing_keys.append(key)

# ---- Print summary ----
total_experiments = len(TARGET_EVENTS) * len(BUDGETS) * len(SEED_SETS)
n_with_optuna = sum(1 for v in experiment_params.values() if v is not None)
n_with_default = sum(1 for v in experiment_params.values() if v is None)

print(f"Phase 1 seed  : {PHASE1_SEED_STRATEGY}")
print(f"Stopping      : {STOPPING_STRATEGY}")
print(f"Events        : {len(TARGET_EVENTS)} events")
print(f"Total expts   : {total_experiments} experiments  ({len(TARGET_EVENTS)} events x {len(BUDGETS)} budgets x {len(SEED_SETS)} seeds)")
print(f"GPUs          : {NUM_GPUS}")
print(f"Optuna params : {n_with_optuna}/{total_experiments} loaded  |  {n_with_default} using defaults")
print(f"Optuna dir    : {OPTUNA_DIR}  (n_trials={N_TRIALS})")
print(f"Results root  : {RESULTS_ROOT}")

if missing_keys:
    print(f"\nWARNING: {len(missing_keys)} experiment(s) missing Optuna results, using defaults:")
    for k in missing_keys[:10]:
        print(f"  {k}")
    if len(missing_keys) > 10:
        print(f"  ... and {len(missing_keys) - 10} more")
# Out:
# Phase 1 seed  : best
# Stopping      : baseline
# Events        : 10 events
# Total expts   : 120 experiments  (10 events x 4 budgets x 3 seeds)
# GPUs          : 2
# Optuna params : 120/120 loaded  |  0 using defaults
# Optuna dir    : D:\Workspace\Co-Training\results\optuna\per_experiment  (n_trials=10)
# Results root  : D:\Workspace\Co-Training\results\gpt-4o\test\run-4

# %% [markdown]
# ## Running Experiments
#
# The cell below runs all 120 experiments (baseline stopping + best-epoch seeding)
# with per-experiment Optuna hyperparameters. Completed experiments are skipped automatically.
#
# > **Runtime estimate**: With 2 GPUs, ~1.5-2.5 hours total.
# > Run overnight or split across sessions -- resume support ensures no work is lost.

# %%
print(f"Total experiments : {total_experiments}")
print(f"Strategy          : {STOPPING_STRATEGY}")
print(f"Phase 1 seeding   : {PHASE1_SEED_STRATEGY}")
print(f"Execution mode    : {'parallel (' + str(NUM_GPUS) + ' GPUs)' if NUM_GPUS > 1 else 'sequential'}")
print()

overall_start = time.time()
tracker = ProgressTracker(total_experiments, 0, overall_start)
event_results = {}  # event -> list[result_dict]

print(f"{'=' * 70}")
print(f"Strategy: {STOPPING_STRATEGY}  |  Phase 1 seeding: {PHASE1_SEED_STRATEGY}")
print(f"Results -> {RESULTS_ROOT}")
print(f"{'=' * 70}")

# Build list of pending experiment configs, skipping completed ones
pending_configs = []   # list of LGCoTrainConfig kwarg dicts
pending_keys = []      # corresponding (event, budget, seed_set) tuples
skipped_results = {}   # (event, budget, seed_set) -> result dict

for event in TARGET_EVENTS:
    for budget in BUDGETS:
        for seed_set in SEED_SETS:
            metrics_path = (
                Path(RESULTS_ROOT) / event / f"{budget}_set{seed_set}" / "metrics.json"
            )

            if metrics_path.exists():
                with open(metrics_path) as f:
                    skipped_results[(event, budget, seed_set)] = json.load(f)
                tracker.update(event, budget, seed_set, "skipped")
                continue

            # Per-experiment Optuna hyperparams (or defaults)
            p = experiment_params.get((event, budget, seed_set)) or DEFAULT_PARAMS
            pending_configs.append(dict(
                event=event,
                budget=budget,
                seed_set=seed_set,
                pseudo_label_source=PSEUDO_LABEL_SOURCE,
                stopping_strategy=STOPPING_STRATEGY,
                phase1_seed_strategy=PHASE1_SEED_STRATEGY,
                lr=p["lr"],
                batch_size=p["batch_size"],
                cotrain_epochs=p["cotrain_epochs"],
                finetune_patience=p["finetune_patience"],
                weight_decay=p["weight_decay"],
                warmup_ratio=p["warmup_ratio"],
                data_root=DATA_ROOT,
                results_root=RESULTS_ROOT,
            ))
            pending_keys.append((event, budget, seed_set))

n_skipped = len(skipped_results)
n_pending = len(pending_configs)
print(f"  Skipped (completed): {n_skipped}  |  Pending: {n_pending}")

# Dispatch pending experiments
parallel_results = {}  # (event, budget, seed_set) -> result dict

if pending_configs and NUM_GPUS > 1:
    print(f"  Dispatching {n_pending} experiments across {NUM_GPUS} GPUs...")
    outcomes = run_experiments_parallel(
        pending_configs,
        num_gpus=NUM_GPUS,
        on_experiment_done=tracker.update,
    )
    for key, outcome in zip(pending_keys, outcomes):
        if outcome["status"] == "done" and outcome["result"] is not None:
            parallel_results[key] = outcome["result"]
        else:
            print(f"  WARNING: {key} failed")

elif pending_configs:
    # Sequential fallback (NUM_GPUS == 1)
    for key, cfg in zip(pending_keys, pending_configs):
        results = run_all_experiments(
            key[0],
            budgets=[key[1]],
            seed_sets=[key[2]],
            pseudo_label_source=PSEUDO_LABEL_SOURCE,
            stopping_strategy=STOPPING_STRATEGY,
            phase1_seed_strategy=PHASE1_SEED_STRATEGY,
            lr=cfg["lr"],
            batch_size=cfg["batch_size"],
            cotrain_epochs=cfg["cotrain_epochs"],
            finetune_patience=cfg["finetune_patience"],
            weight_decay=cfg["weight_decay"],
            warmup_ratio=cfg["warmup_ratio"],
            data_root=DATA_ROOT,
            results_root=RESULTS_ROOT,
            _on_experiment_done=tracker.update,
        )
        if results and results[0] is not None:
            parallel_results[key] = results[0]

# Merge all results into per-event lists
all_results_flat = {**skipped_results, **parallel_results}
for event in TARGET_EVENTS:
    evt_results = [
        all_results_flat.get((event, b, s))
        for b in BUDGETS
        for s in SEED_SETS
    ]
    evt_results = [r for r in evt_results if r is not None]
    if evt_results:
        event_results[event] = evt_results
        print(f"\n  {format_summary_table(evt_results, event)}")

total_elapsed = time.time() - overall_start
print(f"\n{'=' * 70}")
print(f"All experiments complete in {total_elapsed / 3600:.2f}h ({total_elapsed / 60:.1f}min)")
# Out:
# Total experiments : 120
# Strategy          : baseline
# Phase 1 seeding   : best
# Execution mode    : parallel (2 GPUs)
#
# ======================================================================
# Strategy: baseline  |  Phase 1 seeding: best
# Results -> D:\Workspace\Co-Training\results\gpt-4o\test\run-4
# ======================================================================
#   Skipped (completed): 0  |  Pending: 120
#   Dispatching 120 experiments across 2 GPUs...
#   [PROGRESS] 1/120 (0.8%)  |  Elapsed: 0.44h  |  ETA: 51.89h  |  done
#   [PROGRESS] 2/120 (1.7%)  |  Elapsed: 0.47h  |  ETA: 27.78h  |  done
#   [PROGRESS] 3/120 (2.5%)  |  Elapsed: 0.64h  |  ETA: 24.88h  |  done
#   [PROGRESS] 4/120 (3.3%)  |  Elapsed: 0.85h  |  ETA: 24.64h  |  done
#   [PROGRESS] 5/120 (4.2%)  |  Elapsed: 0.91h  |  ETA: 20.97h  |  done
#   [PROGRESS] 6/120 (5.0%)  |  Elapsed: 1.09h  |  ETA: 20.62h  |  done
#   [PROGRESS] 7/120 (5.8%)  |  Elapsed: 1.11h  |  ETA: 17.88h  |  done
#   [PROGRESS] 8/120 (6.7%)  |  Elapsed: 1.30h  |  ETA: 18.22h  |  done
#   [PROGRESS] 9/120 (7.5%)  |  Elapsed: 1.49h  |  ETA: 18.40h  |  done
#   [PROGRESS] 10/120 (8.3%)  |  Elapsed: 1.69h  |  ETA: 18.57h  |  done
#   [PROGRESS] 11/120 (9.2%)  |  Elapsed: 1.71h  |  ETA: 16.92h  |  done
#   [PROGRESS] 12/120 (10.0%)  |  Elapsed: 1.80h  |  ETA: 16.19h  |  done
#   [PROGRESS] 13/120 (10.8%)  |  Elapsed: 1.88h  |  ETA: 15.48h  |  done
#   [PROGRESS] 14/120 (11.7%)  |  Elapsed: 1.90h  |  ETA: 14.41h  |  done
#   [PROGRESS] 15/120 (12.5%)  |  Elapsed: 1.94h  |  ETA: 13.55h  |  done
#   [PROGRESS] 16/120 (13.3%)  |  Elapsed: 2.02h  |  ETA: 13.14h  |  done
#   [PROGRESS] 17/120 (14.2%)  |  Elapsed: 2.06h  |  ETA: 12.50h  |  done
#   [PROGRESS] 18/120 (15.0%)  |  Elapsed: 2.07h  |  ETA: 11.74h  |  done
#   [PROGRESS] 19/120 (15.8%)  |  Elapsed: 2.13h  |  ETA: 11.31h  |  done
#   [PROGRESS] 20/120 (16.7%)  |  Elapsed: 2.14h  |  ETA: 10.70h  |  done
#   [PROGRESS] 21/120 (17.5%)  |  Elapsed: 2.23h  |  ETA: 10.52h  |  done
#   [PROGRESS] 22/120 (18.3%)  |  Elapsed: 2.27h  |  ETA: 10.10h  |  done
#   [PROGRESS] 23/120 (19.2%)  |  Elapsed: 2.32h  |  ETA: 9.77h  |  done
#   [PROGRESS] 24/120 (20.0%)  |  Elapsed: 2.39h  |  ETA: 9.56h  |  done
#   [PROGRESS] 25/120 (20.8%)  |  Elapsed: 2.49h  |  ETA: 9.47h  |  done
#   [PROGRESS] 26/120 (21.7%)  |  Elapsed: 2.51h  |  ETA: 9.07h  |  done
#   [PROGRESS] 27/120 (22.5%)  |  Elapsed: 2.70h  |  ETA: 9.30h  |  done
#   [PROGRESS] 28/120 (23.3%)  |  Elapsed: 2.76h  |  ETA: 9.05h  |  done
#   [PROGRESS] 29/120 (24.2%)  |  Elapsed: 2.84h  |  ETA: 8.90h  |  done
#   [PROGRESS] 30/120 (25.0%)  |  Elapsed: 2.90h  |  ETA: 8.69h  |  done
#   [PROGRESS] 31/120 (25.8%)  |  Elapsed: 2.98h  |  ETA: 8.56h  |  done
#   [PROGRESS] 32/120 (26.7%)  |  Elapsed: 3.02h  |  ETA: 8.31h  |  done
#   [PROGRESS] 33/120 (27.5%)  |  Elapsed: 3.08h  |  ETA: 8.13h  |  done
#   [PROGRESS] 34/120 (28.3%)  |  Elapsed: 3.17h  |  ETA: 8.02h  |  done
#   [PROGRESS] 35/120 (29.2%)  |  Elapsed: 3.31h  |  ETA: 8.03h  |  done
#   [PROGRESS] 36/120 (30.0%)  |  Elapsed: 3.36h  |  ETA: 7.84h  |  done
#   [PROGRESS] 37/120 (30.8%)  |  Elapsed: 3.52h  |  ETA: 7.90h  |  done
#   [PROGRESS] 38/120 (31.7%)  |  Elapsed: 3.74h  |  ETA: 8.06h  |  done
#   [PROGRESS] 39/120 (32.5%)  |  Elapsed: 3.87h  |  ETA: 8.05h  |  done
#   [PROGRESS] 40/120 (33.3%)  |  Elapsed: 4.03h  |  ETA: 8.06h  |  done
#   [PROGRESS] 41/120 (34.2%)  |  Elapsed: 4.09h  |  ETA: 7.88h  |  done
#   [PROGRESS] 42/120 (35.0%)  |  Elapsed: 4.45h  |  ETA: 8.26h  |  done
#   [PROGRESS] 43/120 (35.8%)  |  Elapsed: 4.57h  |  ETA: 8.19h  |  done
#   [PROGRESS] 44/120 (36.7%)  |  Elapsed: 4.77h  |  ETA: 8.24h  |  done
#   [PROGRESS] 45/120 (37.5%)  |  Elapsed: 4.79h  |  ETA: 7.98h  |  done
#   [PROGRESS] 46/120 (38.3%)  |  Elapsed: 4.94h  |  ETA: 7.95h  |  done
#   [PROGRESS] 47/120 (39.2%)  |  Elapsed: 5.05h  |  ETA: 7.85h  |  done
#   [PROGRESS] 48/120 (40.0%)  |  Elapsed: 5.10h  |  ETA: 7.65h  |  done
#   [PROGRESS] 49/120 (40.8%)  |  Elapsed: 5.32h  |  ETA: 7.71h  |  done
#   [PROGRESS] 50/120 (41.7%)  |  Elapsed: 5.39h  |  ETA: 7.55h  |  done
#   [PROGRESS] 51/120 (42.5%)  |  Elapsed: 5.61h  |  ETA: 7.59h  |  done
#   [PROGRESS] 52/120 (43.3%)  |  Elapsed: 5.69h  |  ETA: 7.44h  |  done
#   [PROGRESS] 53/120 (44.2%)  |  Elapsed: 5.81h  |  ETA: 7.35h  |  done
#   [PROGRESS] 54/120 (45.0%)  |  Elapsed: 5.92h  |  ETA: 7.24h  |  done
#   [PROGRESS] 55/120 (45.8%)  |  Elapsed: 6.01h  |  ETA: 7.10h  |  done
#   [PROGRESS] 56/120 (46.7%)  |  Elapsed: 6.22h  |  ETA: 7.11h  |  done
#   [PROGRESS] 57/120 (47.5%)  |  Elapsed: 6.30h  |  ETA: 6.96h  |  done
#   [PROGRESS] 58/120 (48.3%)  |  Elapsed: 6.48h  |  ETA: 6.93h  |  done
#   [PROGRESS] 59/120 (49.2%)  |  Elapsed: 6.57h  |  ETA: 6.80h  |  done
#   [PROGRESS] 60/120 (50.0%)  |  Elapsed: 6.73h  |  ETA: 6.73h  |  done
#   [PROGRESS] 61/120 (50.8%)  |  Elapsed: 6.81h  |  ETA: 6.58h  |  done
#   [PROGRESS] 62/120 (51.7%)  |  Elapsed: 7.07h  |  ETA: 6.62h  |  done
#   [PROGRESS] 63/120 (52.5%)  |  Elapsed: 7.42h  |  ETA: 6.71h  |  done
#   [PROGRESS] 64/120 (53.3%)  |  Elapsed: 7.48h  |  ETA: 6.55h  |  done
#   [PROGRESS] 65/120 (54.2%)  |  Elapsed: 7.67h  |  ETA: 6.49h  |  done
#   [PROGRESS] 66/120 (55.0%)  |  Elapsed: 7.69h  |  ETA: 6.29h  |  done
#   [PROGRESS] 67/120 (55.8%)  |  Elapsed: 7.87h  |  ETA: 6.22h  |  done
#   [PROGRESS] 68/120 (56.7%)  |  Elapsed: 7.89h  |  ETA: 6.03h  |  done
#   [PROGRESS] 69/120 (57.5%)  |  Elapsed: 8.13h  |  ETA: 6.01h  |  done
#   [PROGRESS] 70/120 (58.3%)  |  Elapsed: 8.17h  |  ETA: 5.84h  |  done
#   [PROGRESS] 71/120 (59.2%)  |  Elapsed: 8.44h  |  ETA: 5.82h  |  done
#   [PROGRESS] 72/120 (60.0%)  |  Elapsed: 8.67h  |  ETA: 5.78h  |  done
#   [PROGRESS] 73/120 (60.8%)  |  Elapsed: 8.77h  |  ETA: 5.65h  |  done
#   [PROGRESS] 74/120 (61.7%)  |  Elapsed: 9.13h  |  ETA: 5.68h  |  done
#   [PROGRESS] 75/120 (62.5%)  |  Elapsed: 9.33h  |  ETA: 5.60h  |  done
#   [PROGRESS] 76/120 (63.3%)  |  Elapsed: 9.37h  |  ETA: 5.43h  |  done
#   [PROGRESS] 77/120 (64.2%)  |  Elapsed: 9.53h  |  ETA: 5.32h  |  done
#   [PROGRESS] 78/120 (65.0%)  |  Elapsed: 9.86h  |  ETA: 5.31h  |  done
#   [PROGRESS] 79/120 (65.8%)  |  Elapsed: 10.01h  |  ETA: 5.19h  |  done
#   [PROGRESS] 80/120 (66.7%)  |  Elapsed: 10.10h  |  ETA: 5.05h  |  done
#   [PROGRESS] 81/120 (67.5%)  |  Elapsed: 10.30h  |  ETA: 4.96h  |  done
#   [PROGRESS] 82/120 (68.3%)  |  Elapsed: 10.61h  |  ETA: 4.92h  |  done
#   [PROGRESS] 83/120 (69.2%)  |  Elapsed: 10.66h  |  ETA: 4.75h  |  done
#   [PROGRESS] 84/120 (70.0%)  |  Elapsed: 10.90h  |  ETA: 4.67h  |  done
#   [PROGRESS] 85/120 (70.8%)  |  Elapsed: 10.91h  |  ETA: 4.49h  |  done
#   [PROGRESS] 86/120 (71.7%)  |  Elapsed: 11.13h  |  ETA: 4.40h  |  done
#   [PROGRESS] 87/120 (72.5%)  |  Elapsed: 11.19h  |  ETA: 4.25h  |  done
#   [PROGRESS] 88/120 (73.3%)  |  Elapsed: 11.47h  |  ETA: 4.17h  |  done
#   [PROGRESS] 89/120 (74.2%)  |  Elapsed: 11.57h  |  ETA: 4.03h  |  done
#   [PROGRESS] 90/120 (75.0%)  |  Elapsed: 11.78h  |  ETA: 3.93h  |  done
#   [PROGRESS] 91/120 (75.8%)  |  Elapsed: 11.94h  |  ETA: 3.81h  |  done
#   [PROGRESS] 92/120 (76.7%)  |  Elapsed: 11.99h  |  ETA: 3.65h  |  done
#   [PROGRESS] 93/120 (77.5%)  |  Elapsed: 12.15h  |  ETA: 3.53h  |  done
#   [PROGRESS] 94/120 (78.3%)  |  Elapsed: 12.31h  |  ETA: 3.40h  |  done
#   [PROGRESS] 95/120 (79.2%)  |  Elapsed: 12.48h  |  ETA: 3.28h  |  done
#   [PROGRESS] 96/120 (80.0%)  |  Elapsed: 12.54h  |  ETA: 3.13h  |  done
#   [PROGRESS] 97/120 (80.8%)  |  Elapsed: 12.57h  |  ETA: 2.98h  |  done
#   [PROGRESS] 98/120 (81.7%)  |  Elapsed: 12.60h  |  ETA: 2.83h  |  done
#   [PROGRESS] 99/120 (82.5%)  |  Elapsed: 12.66h  |  ETA: 2.68h  |  done
#   [PROGRESS] 100/120 (83.3%)  |  Elapsed: 12.69h  |  ETA: 2.54h  |  done
#   [PROGRESS] 101/120 (84.2%)  |  Elapsed: 12.72h  |  ETA: 2.39h  |  done
#   [PROGRESS] 102/120 (85.0%)  |  Elapsed: 12.80h  |  ETA: 2.26h  |  done
#   [PROGRESS] 103/120 (85.8%)  |  Elapsed: 12.81h  |  ETA: 2.11h  |  done
#   [PROGRESS] 104/120 (86.7%)  |  Elapsed: 12.90h  |  ETA: 1.98h  |  done
#   [PROGRESS] 105/120 (87.5%)  |  Elapsed: 12.92h  |  ETA: 1.85h  |  done
#   [PROGRESS] 106/120 (88.3%)  |  Elapsed: 12.96h  |  ETA: 1.71h  |  done
#   [PROGRESS] 107/120 (89.2%)  |  Elapsed: 12.96h  |  ETA: 1.58h  |  done
#   [PROGRESS] 108/120 (90.0%)  |  Elapsed: 13.05h  |  ETA: 1.45h  |  done
#   [PROGRESS] 109/120 (90.8%)  |  Elapsed: 13.41h  |  ETA: 1.35h  |  done
#   [PROGRESS] 110/120 (91.7%)  |  Elapsed: 13.49h  |  ETA: 1.23h  |  done
#   [PROGRESS] 111/120 (92.5%)  |  Elapsed: 13.73h  |  ETA: 1.11h  |  done
#   [PROGRESS] 112/120 (93.3%)  |  Elapsed: 13.93h  |  ETA: 0.99h  |  done
#   [PROGRESS] 113/120 (94.2%)  |  Elapsed: 13.99h  |  ETA: 0.87h  |  done
#   [PROGRESS] 114/120 (95.0%)  |  Elapsed: 14.24h  |  ETA: 0.75h  |  done
#   [PROGRESS] 115/120 (95.8%)  |  Elapsed: 14.26h  |  ETA: 0.62h  |  done
#   [PROGRESS] 116/120 (96.7%)  |  Elapsed: 14.45h  |  ETA: 0.50h  |  done
#   [PROGRESS] 117/120 (97.5%)  |  Elapsed: 14.60h  |  ETA: 0.37h  |  done
#   [PROGRESS] 118/120 (98.3%)  |  Elapsed: 14.65h  |  ETA: 0.25h  |  done
#   [PROGRESS] 119/120 (99.2%)  |  Elapsed: 14.81h  |  ETA: 0.12h  |  done
#   [PROGRESS] 120/120 (100.0%)  |  Elapsed: 14.86h  |  ETA: 0.00h  |  done
#
#   === Results for california_wildfires_2018 ===
#
# Budget    Seed 1              Seed 2              Seed 3                  Mean       Std
#            ErrR%  MacF1   ErrR%  MacF1   ErrR%  MacF1     ErrR%     MacF1
# -------------------------------------------------------------------------
#      5     28.61 0.5430   29.98 0.5897   27.24 0.6297  28.61+/-1.37   0.5875+/-0.0434
#     10     28.06 0.6125   28.06 0.5895   27.99 0.6468  28.04+/-0.04   0.6163+/-0.0288
#     25     26.90 0.6488   27.10 0.6508   30.18 0.6122  28.06+/-1.84   0.6372+/-0.0217
#     50     27.17 0.6538   27.38 0.6457   27.17 0.6539  27.24+/-0.12   0.6511+/-0.0047
#
#   === Results for canada_wildfires_2016 ===
#
# Budget    Seed 1              Seed 2              Seed 3                  Mean       Std
#            ErrR%  MacF1   ErrR%  MacF1   ErrR%  MacF1     ErrR%     MacF1
# -------------------------------------------------------------------------
#      5     24.94 0.5724   22.70 0.5740   23.60 0.6420  23.75+/-1.13   0.5961+/-0.0397
#     10     26.29 0.5997   24.49 0.5533   23.60 0.5398  24.79+/-1.37   0.5643+/-0.0314
#     25     23.37 0.5984   26.52 0.5850   21.80 0.5826  23.90+/-2.40   0.5887+/-0.0085
#     50     23.82 0.6193   26.52 0.5765   23.82 0.6153  24.72+/-1.56   0.6037+/-0.0237
#
#   === Results for cyclone_idai_2019 ===
#
# Budget    Seed 1              Seed 2              Seed 3                  Mean       Std
#            ErrR%  MacF1   ErrR%  MacF1   ErrR%  MacF1     ErrR%     MacF1
# -------------------------------------------------------------------------
#      5     22.98 0.5422   23.23 0.5313   25.42 0.5085  23.88+/-1.34   0.5273+/-0.0172
#     10     23.36 0.5628   24.78 0.5256   23.88 0.5571  24.01+/-0.71   0.5485+/-0.0200
#     25     29.40 0.5940   30.04 0.6149   34.79 0.5528  31.41+/-2.95   0.5872+/-0.0316
#     50     30.94 0.5989   27.21 0.6250   34.79 0.5887  30.98+/-3.79   0.6042+/-0.0187
#
#   === Results for hurricane_dorian_2019 ===
#
# Budget    Seed 1              Seed 2              Seed 3                  Mean       Std
#            ErrR%  MacF1   ErrR%  MacF1   ErrR%  MacF1     ErrR%     MacF1
# -------------------------------------------------------------------------
#      5     37.80 0.5540   38.66 0.5520   37.80 0.5494  38.09+/-0.50   0.5518+/-0.0023
#     10     39.66 0.5628   38.33 0.5798   37.00 0.5910  38.33+/-1.33   0.5779+/-0.0142
#     25     41.31 0.5255   36.60 0.5606   36.34 0.5565  38.09+/-2.80   0.5475+/-0.0191
#     50     35.74 0.5929   33.36 0.6142   37.07 0.5955  35.39+/-1.88   0.6009+/-0.0116
#
#   === Results for hurricane_florence_2018 ===
#
# Budget    Seed 1              Seed 2              Seed 3                  Mean       Std
#            ErrR%  MacF1   ErrR%  MacF1   ErrR%  MacF1     ErrR%     MacF1
# -------------------------------------------------------------------------
#      5     25.30 0.6576   24.25 0.6572   25.62 0.6466  25.06+/-0.72   0.6538+/-0.0062
#     10     23.61 0.6607   25.06 0.6551   25.22 0.6577  24.63+/-0.89   0.6579+/-0.0028
#     25     26.43 0.6735   24.09 0.6810   27.07 0.6771  25.87+/-1.57   0.6772+/-0.0038
#     50     25.62 0.6808   24.25 0.6693   24.01 0.6714  24.63+/-0.87   0.6738+/-0.0061
#
#   === Results for hurricane_harvey_2017 ===
#
# Budget    Seed 1              Seed 2              Seed 3                  Mean       Std
#            ErrR%  MacF1   ErrR%  MacF1   ErrR%  MacF1     ErrR%     MacF1
# -------------------------------------------------------------------------
#      5     30.58 0.6490   32.58 0.6283   32.69 0.6335  31.95+/-1.18   0.6369+/-0.0108
#     10     31.02 0.6448   33.19 0.6239   33.57 0.6033  32.59+/-1.37   0.6240+/-0.0207
#     25     29.03 0.6624   28.37 0.6829   34.68 0.6044  30.69+/-3.47   0.6499+/-0.0407
#     50     28.59 0.6691   28.70 0.6798   30.19 0.6619  29.16+/-0.90   0.6703+/-0.0090
#
#   === Results for hurricane_irma_2017 ===
#
# Budget    Seed 1              Seed 2              Seed 3                  Mean       Std
#            ErrR%  MacF1   ErrR%  MacF1   ErrR%  MacF1     ErrR%     MacF1
# -------------------------------------------------------------------------
#      5     35.12 0.6307   35.28 0.6237   37.70 0.6008  36.04+/-1.44   0.6184+/-0.0156
#     10     34.64 0.6336   34.96 0.6278   36.41 0.6122  35.34+/-0.94   0.6245+/-0.0111
#     25     33.46 0.6425   32.49 0.6462   33.08 0.6445  33.01+/-0.49   0.6444+/-0.0019
#     50     34.64 0.6351   32.92 0.6510   31.69 0.6570  33.08+/-1.48   0.6477+/-0.0113
#
#   === Results for hurricane_maria_2017 ===
#
# Budget    Seed 1              Seed 2              Seed 3                  Mean       Std
#            ErrR%  MacF1   ErrR%  MacF1   ErrR%  MacF1     ErrR%     MacF1
# -------------------------------------------------------------------------
#      5     34.67 0.6208   30.93 0.6539   31.55 0.6493  32.39+/-2.01   0.6413+/-0.0179
#     10     37.73 0.5805   31.69 0.6489   31.00 0.6596  33.47+/-3.70   0.6297+/-0.0429
#     25     31.48 0.6622   30.37 0.6842   31.55 0.6580  31.14+/-0.66   0.6681+/-0.0141
#     50     33.01 0.6464   28.85 0.6734   28.43 0.6855  30.10+/-2.53   0.6684+/-0.0200
#
#   === Results for kaikoura_earthquake_2016 ===
#
# Budget    Seed 1              Seed 2              Seed 3                  Mean       Std
#            ErrR%  MacF1   ErrR%  MacF1   ErrR%  MacF1     ErrR%     MacF1
# -------------------------------------------------------------------------
#      5     28.97 0.6469   28.05 0.6478   25.98 0.6707  27.66+/-1.53   0.6551+/-0.0135
#     10     26.21 0.7144   28.05 0.6578   26.44 0.6776  26.90+/-1.00   0.6833+/-0.0287
#     25     24.83 0.7255   25.52 0.6756   28.97 0.6456  26.44+/-2.22   0.6823+/-0.0404
#     50     22.53 0.7464   25.75 0.6777   25.52 0.6965  24.60+/-1.80   0.7069+/-0.0355
#
#   === Results for kerala_floods_2018 ===
#
# Budget    Seed 1              Seed 2              Seed 3                  Mean       Std
#            ErrR%  MacF1   ErrR%  MacF1   ErrR%  MacF1     ErrR%     MacF1
# -------------------------------------------------------------------------
#      5     30.34 0.5657   29.01 0.5651   29.84 0.5551  29.73+/-0.67   0.5620+/-0.0059
#     10     30.40 0.5424   32.17 0.5628   29.90 0.5487  30.83+/-1.19   0.5513+/-0.0104
#     25     29.90 0.5660   34.45 0.5413   29.84 0.5498  31.39+/-2.65   0.5524+/-0.0125
#     50     34.96 0.5637   32.87 0.5405   32.74 0.5517  33.52+/-1.24   0.5520+/-0.0116
#
# ======================================================================
# All experiments complete in 14.86h (891.9min)

# %%
# Load any results that already existed (re-run safe)
for event in TARGET_EVENTS:
    if event in event_results:
        continue
    results = []
    for budget in BUDGETS:
        for seed_set in SEED_SETS:
            path = Path(RESULTS_ROOT) / event / f"{budget}_set{seed_set}" / "metrics.json"
            if path.exists():
                with open(path) as f:
                    results.append(json.load(f))
    if results:
        event_results[event] = results

# Build lookup: lookup[event][(budget, seed_set)] -> result
lookup = {}
for event in TARGET_EVENTS:
    lookup[event] = {}
    for r in event_results.get(event, []):
        if r is not None:
            lookup[event][(r["budget"], r["seed_set"])] = r

# Coverage report
n_loaded = sum(len(lookup[e]) for e in TARGET_EVENTS)
print(f"Experiments loaded: {n_loaded}/{total_experiments}  ({100 * n_loaded / total_experiments:.0f}%)")
# Out:
# Experiments loaded: 120/120  (100%)

# %%
# Per-event summary tables: macro-F1 per budget (mean +/- std across 3 seeds)

col_w = 18

for event in TARGET_EVENTS:
    print(f"\n{'=' * 70}")
    print(f"Event: {event}")
    print(f"{'=' * 70}")

    print(f"{'Budget':<8}" + "".join(f" {'Macro-F1':<{col_w}}" for _ in ['']) + "  Error Rate")
    print("-" * 50)

    for budget in BUDGETS:
        f1s = [
            lookup[event].get((budget, s), {}).get("test_macro_f1")
            for s in SEED_SETS
        ]
        errs = [
            lookup[event].get((budget, s), {}).get("test_error_rate")
            for s in SEED_SETS
        ]
        f1s = [f for f in f1s if f is not None]
        errs = [e for e in errs if e is not None]

        if f1s:
            f_m = statistics.mean(f1s)
            f_sd = statistics.stdev(f1s) if len(f1s) >= 2 else 0.0
            e_m = statistics.mean(errs) if errs else 0
            print(f"{budget:<8} {f_m:.4f}+/-{f_sd:.4f}        {e_m:.2f}%")
        else:
            print(f"{budget:<8} N/A")
# Out:
# ======================================================================
# Event: california_wildfires_2018
# ======================================================================
# Budget   Macro-F1            Error Rate
# --------------------------------------------------
# 5        0.5875+/-0.0434        28.61%
# 10       0.6163+/-0.0288        28.04%
# 25       0.6372+/-0.0217        28.06%
# 50       0.6511+/-0.0047        27.24%
#
# ======================================================================
# Event: canada_wildfires_2016
# ======================================================================
# Budget   Macro-F1            Error Rate
# --------------------------------------------------
# 5        0.5961+/-0.0397        23.75%
# 10       0.5643+/-0.0314        24.79%
# 25       0.5887+/-0.0085        23.90%
# 50       0.6037+/-0.0237        24.72%
#
# ======================================================================
# Event: cyclone_idai_2019
# ======================================================================
# Budget   Macro-F1            Error Rate
# --------------------------------------------------
# 5        0.5273+/-0.0172        23.88%
# 10       0.5485+/-0.0200        24.01%
# 25       0.5872+/-0.0316        31.41%
# 50       0.6042+/-0.0187        30.98%
#
# ======================================================================
# Event: hurricane_dorian_2019
# ======================================================================
# Budget   Macro-F1            Error Rate
# --------------------------------------------------
# 5        0.5518+/-0.0023        38.09%
# 10       0.5779+/-0.0142        38.33%
# 25       0.5475+/-0.0191        38.09%
# 50       0.6009+/-0.0116        35.39%
#
# ======================================================================
# Event: hurricane_florence_2018
# ======================================================================
# Budget   Macro-F1            Error Rate
# --------------------------------------------------
# 5        0.6538+/-0.0062        25.06%
# 10       0.6579+/-0.0028        24.63%
# 25       0.6772+/-0.0038        25.87%
# 50       0.6738+/-0.0061        24.63%
#
# ======================================================================
# Event: hurricane_harvey_2017
# ======================================================================
# Budget   Macro-F1            Error Rate
# --------------------------------------------------
# 5        0.6369+/-0.0108        31.95%
# 10       0.6240+/-0.0207        32.59%
# 25       0.6499+/-0.0407        30.69%
# 50       0.6703+/-0.0090        29.16%
#
# ======================================================================
# Event: hurricane_irma_2017
# ======================================================================
# Budget   Macro-F1            Error Rate
# --------------------------------------------------
# 5        0.6184+/-0.0156        36.04%
# 10       0.6245+/-0.0111        35.34%
# 25       0.6444+/-0.0019        33.01%
# 50       0.6477+/-0.0113        33.08%
#
# ======================================================================
# Event: hurricane_maria_2017
# ======================================================================
# Budget   Macro-F1            Error Rate
# --------------------------------------------------
# 5        0.6413+/-0.0179        32.39%
# 10       0.6297+/-0.0429        33.47%
# 25       0.6681+/-0.0141        31.14%
# 50       0.6684+/-0.0200        30.10%
#
# ======================================================================
# Event: kaikoura_earthquake_2016
# ======================================================================
# Budget   Macro-F1            Error Rate
# --------------------------------------------------
# 5        0.6551+/-0.0135        27.66%
# 10       0.6833+/-0.0287        26.90%
# 25       0.6823+/-0.0404        26.44%
# 50       0.7069+/-0.0355        24.60%
#
# ======================================================================
# Event: kerala_floods_2018
# ======================================================================
# Budget   Macro-F1            Error Rate
# --------------------------------------------------
# 5        0.5620+/-0.0059        29.73%
# 10       0.5513+/-0.0104        30.83%
# 25       0.5524+/-0.0125        31.39%
# 50       0.5520+/-0.0116        33.52%

# %%
# Bar chart: macro-F1 by budget, one subplot per event

n_events = len(TARGET_EVENTS)
ncols = min(5, n_events)
nrows = (n_events + ncols - 1) // ncols
fig, axes = plt.subplots(nrows, ncols, figsize=(4.5 * ncols, 4.5 * nrows), sharey=False)
axes_flat = np.array(axes).flatten() if n_events > 1 else [axes]

for ax, event in zip(axes_flat, TARGET_EVENTS):
    x = np.arange(len(BUDGETS))
    means, errs = [], []
    for budget in BUDGETS:
        f1s = [
            lookup[event].get((budget, s), {}).get("test_macro_f1")
            for s in SEED_SETS
        ]
        f1s = [f for f in f1s if f is not None]
        means.append(statistics.mean(f1s) if f1s else 0)
        errs.append(statistics.stdev(f1s) if len(f1s) >= 2 else 0)

    ax.bar(x, means, 0.6, yerr=errs, capsize=3, color="darkorange", alpha=0.85)
    ax.set_title(event.replace("_", " ").title(), fontsize=9)
    ax.set_xlabel("Budget")
    ax.set_ylabel("Macro-F1")
    ax.set_xticks(x)
    ax.set_xticklabels([str(b) for b in BUDGETS])
    ax.set_ylim(0, 1)
    ax.grid(axis="y", alpha=0.3)

# Hide unused subplots
for ax in axes_flat[n_events:]:
    ax.set_visible(False)

fig.suptitle(
    f"Best-Epoch Phase 1 Seeding (Optuna Hyperparams) -- Baseline Stopping\n"
    f"(pseudo-labels: {PSEUDO_LABEL_SOURCE}, phase1_seed_strategy={PHASE1_SEED_STRATEGY})",
    fontsize=12,
)
plt.tight_layout()
plt.show()

# %%
# Cross-event grand summary: mean macro-F1 across all events per budget

print(f"Grand summary -- mean macro-F1 across all events and seeds")
print(f"  Phase 1 seeding: {PHASE1_SEED_STRATEGY}  |  Stopping: {STOPPING_STRATEGY}")
print()
print(f"{'Budget':<8}" + "  Mean Macro-F1")
print("-" * 35)

all_f1s_total = []
for budget in BUDGETS:
    f1s = [
        lookup[e].get((budget, s), {}).get("test_macro_f1")
        for e in TARGET_EVENTS
        for s in SEED_SETS
    ]
    f1s = [f for f in f1s if f is not None]
    if f1s:
        m = statistics.mean(f1s)
        sd = statistics.stdev(f1s) if len(f1s) >= 2 else 0
        all_f1s_total.extend(f1s)
        print(f"{budget:<8}  {m:.4f} +/- {sd:.4f}  (n={len(f1s)})")
    else:
        print(f"{budget:<8}  N/A")

if all_f1s_total:
    overall = statistics.mean(all_f1s_total)
    print(f"{'Overall':<8}  {overall:.4f}  (n={len(all_f1s_total)})")
# Out:
# Grand summary -- mean macro-F1 across all events and seeds
#   Phase 1 seeding: best  |  Stopping: baseline
#
# Budget    Mean Macro-F1
# -----------------------------------
# 5         0.6030 +/- 0.0473  (n=30)
# 10        0.6078 +/- 0.0484  (n=30)
# 25        0.6235 +/- 0.0526  (n=30)
# 50        0.6379 +/- 0.0471  (n=30)
# Overall   0.6180  (n=120)

# %% [markdown]
# ## Comparison: `last` vs `best` Phase 1 Seeding
#
# Load Notebook 10's baseline results (`phase1_seed_strategy="last"`, same Optuna hyperparams)
# and compare them side-by-side with the `best`-seeding results from this notebook.

# %%
# Load Notebook 10 baseline results (last seeding, same Optuna hyperparams)
LAST_SEEDING_ROOT = str(repo_root / "results" / PSEUDO_LABEL_SOURCE / "optuna-stop" / "baseline")

last_lookup = {}  # event -> {(budget, seed): result}
for event in TARGET_EVENTS:
    last_lookup[event] = {}
    for budget in BUDGETS:
        for seed_set in SEED_SETS:
            path = (
                Path(LAST_SEEDING_ROOT) / event / f"{budget}_set{seed_set}" / "metrics.json"
            )
            if path.exists():
                with open(path) as f:
                    last_lookup[event][(budget, seed_set)] = json.load(f)

n_last = sum(len(last_lookup[e]) for e in TARGET_EVENTS)
print(f"Loaded {n_last} 'last' seeding results from: {LAST_SEEDING_ROOT}")
print()

# ---- Side-by-side comparison per event x budget ----
print(f"'last' (NB10) vs 'best' (NB11): Mean Test Macro-F1")
print("=" * 90)

for event in TARGET_EVENTS:
    print(f"\nEvent: {event}")
    print(f"{'Budget':<8} {'Last':>12} {'Best':>12} {'Delta':>10}")
    print("-" * 45)

    for budget in BUDGETS:
        last_f1s = [
            last_lookup[event].get((budget, s), {}).get("test_macro_f1")
            for s in SEED_SETS
        ]
        best_f1s = [
            lookup[event].get((budget, s), {}).get("test_macro_f1")
            for s in SEED_SETS
        ]
        last_f1s = [f for f in last_f1s if f is not None]
        best_f1s = [f for f in best_f1s if f is not None]

        l_str = f"{statistics.mean(last_f1s):.4f}" if last_f1s else "N/A"
        b_str = f"{statistics.mean(best_f1s):.4f}" if best_f1s else "N/A"

        if last_f1s and best_f1s:
            d = statistics.mean(best_f1s) - statistics.mean(last_f1s)
            sign = "+" if d >= 0 else ""
            d_str = f"{sign}{d:.4f}"
        else:
            d_str = "N/A"

        print(f"{budget:<8} {l_str:>12} {b_str:>12} {d_str:>10}")

# ---- Grand summary ----
print(f"\n{'=' * 90}")
print(f"Grand Summary: 'last' vs 'best' Phase 1 Seeding (baseline stopping, all events)")
print(f"{'Budget':<8} {'Last':>12} {'Best':>12} {'Delta':>10}")
print("-" * 45)

all_last_vals = []
all_best_vals = []

for budget in BUDGETS:
    last_f1s = [
        last_lookup[e].get((budget, s), {}).get("test_macro_f1")
        for e in TARGET_EVENTS for s in SEED_SETS
    ]
    best_f1s = [
        lookup[e].get((budget, s), {}).get("test_macro_f1")
        for e in TARGET_EVENTS for s in SEED_SETS
    ]
    last_f1s = [f for f in last_f1s if f is not None]
    best_f1s = [f for f in best_f1s if f is not None]

    l_str = f"{statistics.mean(last_f1s):.4f}" if last_f1s else "N/A"
    b_str = f"{statistics.mean(best_f1s):.4f}" if best_f1s else "N/A"

    if last_f1s and best_f1s:
        d = statistics.mean(best_f1s) - statistics.mean(last_f1s)
        sign = "+" if d >= 0 else ""
        d_str = f"{sign}{d:.4f}"
        all_last_vals.extend(last_f1s)
        all_best_vals.extend(best_f1s)
    else:
        d_str = "N/A"

    print(f"{budget:<8} {l_str:>12} {b_str:>12} {d_str:>10}")

if all_last_vals and all_best_vals:
    d_overall = statistics.mean(all_best_vals) - statistics.mean(all_last_vals)
    sign = "+" if d_overall >= 0 else ""
    print(f"{'Overall':<8} {statistics.mean(all_last_vals):>12.4f} {statistics.mean(all_best_vals):>12.4f} {sign}{d_overall:>9.4f}")

# ---- Bar chart: last vs best per budget ----
fig, ax = plt.subplots(figsize=(8, 5))
x = np.arange(len(BUDGETS))
w = 0.35

last_means = []
best_means = []
for budget in BUDGETS:
    lf = [last_lookup[e].get((budget, s), {}).get("test_macro_f1")
          for e in TARGET_EVENTS for s in SEED_SETS]
    bf = [lookup[e].get((budget, s), {}).get("test_macro_f1")
          for e in TARGET_EVENTS for s in SEED_SETS]
    lf = [f for f in lf if f is not None]
    bf = [f for f in bf if f is not None]
    last_means.append(statistics.mean(lf) if lf else 0)
    best_means.append(statistics.mean(bf) if bf else 0)

ax.bar(x - w / 2, last_means, w, label="Last epoch seeding (NB 10)", color="steelblue", alpha=0.85)
ax.bar(x + w / 2, best_means, w, label="Best epoch seeding (NB 11)", color="darkorange", alpha=0.85)

ax.set_xticks(x)
ax.set_xticklabels([str(b) for b in BUDGETS])
ax.set_xlabel("Budget (labels per class)")
ax.set_ylabel("Mean Test Macro-F1")
ax.set_ylim(0, 1)
ax.set_title(
    f"Phase 1 Seeding: Last vs Best Epoch (Optuna Hyperparams, Baseline Stopping)\n"
    f"Mean across all events and seeds (pseudo-labels: {PSEUDO_LABEL_SOURCE})",
    fontsize=11,
)
ax.legend(fontsize=9)
ax.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Loaded 120 'last' seeding results from: D:\Workspace\Co-Training\results\gpt-4o\optuna-stop\baseline
#
# 'last' (NB10) vs 'best' (NB11): Mean Test Macro-F1
# ==========================================================================================
#
# Event: california_wildfires_2018
# Budget           Last         Best      Delta
# ---------------------------------------------
# 5              0.6054       0.5875    -0.0179
# 10             0.6317       0.6163    -0.0154
# 25             0.6396       0.6372    -0.0024
# 50             0.6569       0.6511    -0.0058
#
# Event: canada_wildfires_2016
# Budget           Last         Best      Delta
# ---------------------------------------------
# 5              0.5596       0.5961    +0.0366
# 10             0.5680       0.5643    -0.0037
# 25             0.6038       0.5887    -0.0152
# 50             0.6162       0.6037    -0.0125
#
# Event: cyclone_idai_2019
# Budget           Last         Best      Delta
# ---------------------------------------------
# 5              0.5368       0.5273    -0.0095
# 10             0.6005       0.5485    -0.0520
# 25             0.6076       0.5872    -0.0204
# 50             0.5886       0.6042    +0.0156
#
# Event: hurricane_dorian_2019
# Budget           Last         Best      Delta
# ---------------------------------------------
# 5              0.5606       0.5518    -0.0088
# 10             0.5741       0.5779    +0.0037
# 25             0.5584       0.5475    -0.0109
# 50             0.5952       0.6009    +0.0057
#
# Event: hurricane_florence_2018
# Budget           Last         Best      Delta
# ---------------------------------------------
# 5              0.6486       0.6538    +0.0052
# 10             0.6581       0.6579    -0.0002
# 25             0.6922       0.6772    -0.0150
# 50             0.6800       0.6738    -0.0061
#
# Event: hurricane_harvey_2017
# Budget           Last         Best      Delta
# ---------------------------------------------
# 5              0.6254       0.6369    +0.0115
# 10             0.6441       0.6240    -0.0201
# 25             0.6686       0.6499    -0.0187
# 50             0.6745       0.6703    -0.0042
#
# Event: hurricane_irma_2017
# Budget           Last         Best      Delta
# ---------------------------------------------
# 5              0.6207       0.6184    -0.0024
# 10             0.6243       0.6245    +0.0002
# 25             0.6529       0.6444    -0.0085
# 50             0.6564       0.6477    -0.0087
#
# Event: hurricane_maria_2017
# Budget           Last         Best      Delta
# ---------------------------------------------
# 5              0.6480       0.6413    -0.0067
# 10             0.6293       0.6297    +0.0003
# 25             0.6705       0.6681    -0.0023
# 50             0.6761       0.6684    -0.0077
#
# Event: kaikoura_earthquake_2016
# Budget           Last         Best      Delta
# ---------------------------------------------
# 5              0.6618       0.6551    -0.0067
# 10             0.6795       0.6833    +0.0038
# 25             0.7012       0.6823    -0.0189
# 50             0.7066       0.7069    +0.0003
#
# Event: kerala_floods_2018
# Budget           Last         Best      Delta
# ---------------------------------------------
# 5              0.5586       0.5620    +0.0034
# 10             0.5513       0.5513    +0.0000
# 25             0.5468       0.5524    +0.0056
# 50             0.5666       0.5520    -0.0147
#
# ==========================================================================================
# Grand Summary: 'last' vs 'best' Phase 1 Seeding (baseline stopping, all events)
# Budget           Last         Best      Delta
# ---------------------------------------------
# 5              0.6026       0.6030    +0.0005
# 10             0.6161       0.6078    -0.0083
# 25             0.6342       0.6235    -0.0107
# 50             0.6417       0.6379    -0.0038
# Overall        0.6236       0.6180   -0.0056

# %%
# Per-class F1 heatmaps at budget=5 (hardest case)
# Compare last vs best seeding side by side

from lg_cotrain.data_loading import CLASS_LABELS

HEATMAP_BUDGET = 5
print(f"Per-class F1 heatmaps at budget={HEATMAP_BUDGET}: 'last' vs 'best' seeding")

for event in TARGET_EVENTS:
    data_rows = []
    row_labels = []

    for label, lkp in [("last (NB10)", last_lookup), ("best (NB11)", lookup)]:
        per_class_all_seeds = [
            lkp[event][(HEATMAP_BUDGET, s)]["test_per_class_f1"]
            for s in SEED_SETS
            if (HEATMAP_BUDGET, s) in lkp[event]
            and "test_per_class_f1" in lkp[event][(HEATMAP_BUDGET, s)]
        ]
        if per_class_all_seeds:
            mean_per_class = [
                statistics.mean(seed[i] for seed in per_class_all_seeds)
                for i in range(len(per_class_all_seeds[0]))
            ]
            data_rows.append(mean_per_class)
            row_labels.append(label)

    if len(data_rows) < 2:
        print(f"  Skipping {event}: insufficient data for comparison.")
        continue

    data = np.array(data_rows)
    n_classes = data.shape[1]
    class_labels = CLASS_LABELS[:n_classes] if n_classes <= len(CLASS_LABELS) else [
        f"class_{i}" for i in range(n_classes)
    ]

    fig, ax = plt.subplots(
        figsize=(max(9, n_classes * 0.75), len(row_labels) * 0.65 + 1.8)
    )
    im = ax.imshow(data, cmap="RdYlGn", aspect="auto", vmin=0, vmax=1)

    ax.set_xticks(range(n_classes))
    ax.set_xticklabels(class_labels, rotation=45, ha="right", fontsize=8)
    ax.set_yticks(range(len(row_labels)))
    ax.set_yticklabels(row_labels, fontsize=9)
    ax.set_title(
        f"{event}  |  Budget={HEATMAP_BUDGET}  |  Per-class F1 (mean across seeds)",
        fontsize=10,
    )

    for i in range(len(row_labels)):
        for j in range(n_classes):
            val = data[i, j]
            color = "black" if 0.25 < val < 0.75 else "white"
            ax.text(j, i, f"{val:.2f}", ha="center", va="center", fontsize=7, color=color)

    fig.colorbar(im, ax=ax, label="F1 Score")
    plt.tight_layout()
    plt.show()
# Out:
# Per-class F1 heatmaps at budget=5: 'last' vs 'best' seeding

# %%
# Phase 1 Best Epoch Analysis
# For each experiment, load phase1_best_epoch and analyze which epochs were selected.
# This gives insight into whether Phase 1 models typically overfit (best epoch < 7).

best_epochs = []  # list of (event, budget, seed_set, best_epoch)
best_epochs_by_budget = {b: [] for b in BUDGETS}

for event in TARGET_EVENTS:
    for budget in BUDGETS:
        for seed_set in SEED_SETS:
            r = lookup[event].get((budget, seed_set))
            if r and r.get("phase1_best_epoch") is not None:
                ep = r["phase1_best_epoch"]
                best_epochs.append((event, budget, seed_set, ep))
                best_epochs_by_budget[budget].append(ep)

print(f"Phase 1 Best Epoch Distribution ({len(best_epochs)} experiments)")
print("=" * 60)

if best_epochs:
    all_ep_vals = [x[3] for x in best_epochs]
    print(f"Overall: mean={statistics.mean(all_ep_vals):.2f}, "
          f"median={statistics.median(all_ep_vals):.1f}, "
          f"min={min(all_ep_vals)}, max={max(all_ep_vals)}")
    print()

    # Per-budget breakdown
    print(f"{'Budget':<8} {'Mean':>6} {'Median':>8} {'Min':>5} {'Max':>5} {'n':>4}")
    print("-" * 40)
    for budget in BUDGETS:
        eps = best_epochs_by_budget[budget]
        if eps:
            print(f"{budget:<8} {statistics.mean(eps):>6.2f} {statistics.median(eps):>8.1f} "
                  f"{min(eps):>5} {max(eps):>5} {len(eps):>4}")

    # Histogram
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))

    # Overall histogram
    ax = axes[0]
    max_epoch = max(all_ep_vals)
    bins = np.arange(0.5, max_epoch + 1.5, 1)
    ax.hist(all_ep_vals, bins=bins, color="darkorange", alpha=0.85, edgecolor="black")
    ax.set_xlabel("Best Phase 1 Epoch (1-indexed)")
    ax.set_ylabel("Count")
    ax.set_title("Overall Distribution of Best Phase 1 Epoch")
    ax.set_xticks(range(1, max_epoch + 1))
    ax.grid(axis="y", alpha=0.3)

    # Per-budget histogram (stacked)
    ax = axes[1]
    budget_data = [best_epochs_by_budget[b] for b in BUDGETS]
    ax.hist(budget_data, bins=bins, label=[f"Budget={b}" for b in BUDGETS],
            alpha=0.85, edgecolor="black", stacked=True)
    ax.set_xlabel("Best Phase 1 Epoch (1-indexed)")
    ax.set_ylabel("Count")
    ax.set_title("Best Phase 1 Epoch by Budget")
    ax.set_xticks(range(1, max_epoch + 1))
    ax.legend(fontsize=8)
    ax.grid(axis="y", alpha=0.3)

    plt.tight_layout()
    plt.show()

    # How often is the best epoch NOT the last epoch?
    n_not_last = sum(1 for ep in all_ep_vals if ep < max_epoch)
    pct_not_last = 100 * n_not_last / len(all_ep_vals)
    print(f"\nBest epoch != last epoch: {n_not_last}/{len(all_ep_vals)} ({pct_not_last:.1f}%)")
    print("(A high percentage supports the hypothesis that Phase 1 models often overfit.)")
else:
    print("No phase1_best_epoch data found. Run experiments first.")
# Out:
# Phase 1 Best Epoch Distribution (120 experiments)
# ============================================================
# Overall: mean=6.58, median=7.0, min=2, max=7
#
# Budget     Mean   Median   Min   Max    n
# ----------------------------------------
# 5          6.43      7.0     2     7   30
# 10         6.53      7.0     4     7   30
# 25         6.73      7.0     5     7   30
# 50         6.60      7.0     5     7   30
# Best epoch != last epoch: 33/120 (27.5%)
# (A high percentage supports the hypothesis that Phase 1 models often overfit.)

# %%
# Rebuild multi-tab dashboard with all strategy result sets.

from lg_cotrain.dashboard import discover_result_sets, generate_html_multi

TOP_RESULTS_ROOT = str(repo_root / "results")

result_sets = discover_result_sets(TOP_RESULTS_ROOT)
print(f"Discovered {len(result_sets)} model(s):")
for model, types in result_sets.items():
    for exp_type, experiments in types.items():
        for name, path in experiments:
            print(f"  {model}/{exp_type}/{name:<20} -> {path}")

html = generate_html_multi(result_sets, data_root=DATA_ROOT)
dashboard_path = Path(TOP_RESULTS_ROOT) / "dashboard.html"
dashboard_path.write_text(html, encoding="utf-8")
print(f"\nDashboard written to: {dashboard_path}")
print("Open in a browser to compare all strategies across all budgets and events.")
# Out:
# Discovered 1 model(s):
#   gpt-4o/optuna-stop/baseline             -> D:\Workspace\Co-Training\results\gpt-4o\optuna-stop\baseline
#   gpt-4o/optuna-stop/balanced_dev         -> D:\Workspace\Co-Training\results\gpt-4o\optuna-stop\balanced_dev
#   gpt-4o/optuna-stop/no_early_stopping    -> D:\Workspace\Co-Training\results\gpt-4o\optuna-stop\no_early_stopping
#   gpt-4o/optuna-stop/per_class_patience   -> D:\Workspace\Co-Training\results\gpt-4o\optuna-stop\per_class_patience
#   gpt-4o/optuna-stop/scaled_threshold     -> D:\Workspace\Co-Training\results\gpt-4o\optuna-stop\scaled_threshold
#   gpt-4o/optuna-stop/weighted_macro_f1    -> D:\Workspace\Co-Training\results\gpt-4o\optuna-stop\weighted_macro_f1
#   gpt-4o/test/run-1                -> D:\Workspace\Co-Training\results\gpt-4o\test\run-1
#   gpt-4o/test/run-2                -> D:\Workspace\Co-Training\results\gpt-4o\test\run-2
#   gpt-4o/test/run-3                -> D:\Workspace\Co-Training\results\gpt-4o\test\run-3
#   gpt-4o/test/run-4                -> D:\Workspace\Co-Training\results\gpt-4o\test\run-4
#
# Dashboard written to: D:\Workspace\Co-Training\results\dashboard.html
# Open in a browser to compare all strategies across all budgets and events.
